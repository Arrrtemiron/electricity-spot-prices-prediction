# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../datasets/jcpl_pjm_2017_2023.csv')
data.head()
# Out:
#              timestamp  price
# 0  2017-01-01 00:00:00  25.38
# 1  2017-01-01 01:00:00  24.91
# 2  2017-01-01 02:00:00  24.58
# 3  2017-01-01 03:00:00  24.23
# 4  2017-01-01 04:00:00  24.53

# %%
data.index = data['timestamp']
data.index = pd.to_datetime(data.index)
data.drop(columns=['timestamp'], inplace=True)
data.price.plot()
plt.title('Prices from 2017 to 2023');

# %%
data.resample("M").mean().plot()
plt.title('Месячное преобразование');
