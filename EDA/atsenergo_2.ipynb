# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../datasets/atsenergo_2017_2023_2.csv')
data.head()
# Out:
#              timestamp    price
# 0  2017-01-01 00:00:00  1006.23
# 1  2017-01-01 01:00:00  1003.74
# 2  2017-01-01 02:00:00  1005.05
# 3  2017-01-01 03:00:00  1002.33
# 4  2017-01-01 04:00:00  1002.55

# %%
data.index = data['timestamp']
data.index = pd.to_datetime(data.index)
data.drop(columns=['timestamp'], inplace=True)
data.price.plot()
plt.title('Prices from 2017 to 2023');

# %%
data.resample("M").mean().plot()
plt.title('Месячное преобразование');
